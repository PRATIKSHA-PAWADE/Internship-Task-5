# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
at=pd.read_csv("Attrition.csv")
at.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
at.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
at.shape
# Out:
# (1470, 35)

# %%
at["Attrition"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
at["BusinessTravel"].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
sns.catplot(x='BusinessTravel' , data=at , kind='count', hue='Attrition')
plt.ylabel("Count of Employee")
plt.xlabel("Categories of business travel")
plt.title("Relation between Attrion and BusinessTravel" , color ="limegreen")
# Out:
# Text(0.5, 1.0, 'Relation between Attrion and BusinessTravel')

# %%
at.Attrition.replace({"Yes":1, "No":0},inplace=True)

# %%
df=pd.DataFrame(at.groupby('BusinessTravel').Attrition.sum())
df= df.sort_values('Attrition')

# %%
plt.bar(df.index , df.Attrition)
plt.title("Relation between Attrion and BusinessTravel" , color ="magenta")
# Out:
# Text(0.5, 1.0, 'Relation between Attrion and BusinessTravel')

# %%
plt.pie(df.Attrition , labels = df.index , autopct ="%1.02f%%")
plt.title("Relation between Attrion and BusinessTravel" , color ="darkblue")
plt.show()

# %%
at["Department"].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
df6=pd.DataFrame(at.groupby('Department').Attrition.sum())
df6= df6.sort_values('Attrition')

# %%
plt.bar(df6.index , df6.Attrition , color="deeppink")
plt.title("Relation between Attrtion and Department" , color ="lime")
# Out:
# Text(0.5, 1.0, 'Relation between Attrtion and Department')

# %%
plt.pie(df6.Attrition , labels = df6.index , autopct ="%1.02f%%" , colors =["darkviolet","crimson","seagreen"])
plt.title("Relation between Attrion and Department" , color ="deepskyblue")
plt.show()

# %%
at["DistanceFromHome"].unique()
# Out:
# array([ 1,  8,  2,  3, 24, 23, 27, 16, 15, 26, 19, 21,  5, 11,  9,  7,  6,
#        10,  4, 25, 12, 18, 29, 22, 14, 20, 28, 17, 13])

# %%
sns.pointplot(x='Attrition', y='DistanceFromHome', data=at , color ="limegreen")
plt.grid()
plt.title( 'Relation between Attrion and DistanceFromHome')
plt.show()

# %%
sns.barplot(x='Attrition', y='DistanceFromHome', data=at , color ="crimson")
# Out:
# <Axes: xlabel='Attrition', ylabel='DistanceFromHome'>

# %%
at["Gender"].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
sns.catplot(x='Attrition' , data=at , kind='count', hue='Gender')

# %%
sns.boxplot(x="Attrition",y="JobSatisfaction",data=at)
plt.show()

# %%
sns.barplot(x='JobSatisfaction',y='MonthlyIncome',hue='Attrition' ,data=at)
# Out:
# <Axes: xlabel='JobSatisfaction', ylabel='MonthlyIncome'>

# %%
sns.catplot(x='JobSatisfaction',hue='Attrition' , data=at , kind='count' )

# %%
sns.pointplot(x="JobSatisfaction",y="Attrition",data=at,hue="Gender")
# Out:
# <Axes: xlabel='JobSatisfaction', ylabel='Attrition'>

# %%
sns.boxplot(x="Attrition",y="MonthlyIncome",data=at)
plt.show()

# %%
df2=pd.DataFrame(at.groupby('Attrition').MonthlyIncome.sum())
df2= df2.sort_values('MonthlyIncome')

# %%
plt.bar(df2.index , df2.MonthlyIncome , color="cyan")
plt.title("Relation between Attrion and MonthlyIncome" , color ="deeppink")
plt.xlabel("Attrition")
plt.ylabel("MonthlyIncome")
# Out:
# Text(0, 0.5, 'MonthlyIncome')

# %%
plt.pie(df2.MonthlyIncome , labels = df2.index , autopct ="%1.02f%%" , colors =["darkviolet","crimson","seagreen"])
plt.title("Relation between Attrion and MonthlyIncome" , color ="deepskyblue")
plt.show()

# %%
at["StockOptionLevel"].unique()
# Out:
# array([0, 1, 3, 2])

# %%
sns.catplot(x='Attrition' , data=at , kind='count', hue='OverTime')
plt.xlabel("Attrition")
plt.ylabel("OverTime")
plt.show()

# %%
df3=pd.DataFrame(at.groupby('Attrition').StockOptionLevel.sum())
df3= df3.sort_values('StockOptionLevel')

# %%
plt.bar(df3.index , df3.StockOptionLevel , color="darkblue")
plt.title("Relation between Attrion and StockOptionLevel" , color ="magenta")
plt.xlabel("Attrition")
plt.ylabel("StockOptionLevel")
# Out:
# Text(0, 0.5, 'StockOptionLevel')

# %%
plt.pie(df3.StockOptionLevel , labels = df3.index , autopct ="%1.02f%%" , colors =["darkviolet","crimson","cyan"])
plt.title("Relation between Attrion and StockOptionLevel" , color ="darkcyan")
plt.show()

# %%
df5=pd.DataFrame(at.groupby('Attrition').YearsWithCurrManager.sum())
df5= df5.sort_values('YearsWithCurrManager')

# %%
plt.bar(df5.index , df5.YearsWithCurrManager , color="purple")
plt.title("Relation between Attrion and YearsWithCurrManager" , color ="crimson")
plt.xlabel("Attrition")
plt.ylabel("YearsWithCurrManager")
# Out:
# Text(0, 0.5, 'YearsWithCurrManager')

# %%
plt.pie(df5.YearsWithCurrManager , labels = df5.index , autopct ="%1.02f%%" , colors =["crimson","cyan"])
plt.title("Relation between Attrion and YearsWithCurrManager" , color ="darkcyan")
plt.show()

# %%
df7=pd.DataFrame(at.groupby('Attrition').Age.mean())
df7= df7.sort_values('Age')

# %%
plt.bar(df7.index , df7.Age , color="darkgreen")
plt.title("Relation between Attrion and Age" , color ="purple")
plt.xlabel("Attrition")
plt.ylabel("Age")
# Out:
# Text(0, 0.5, 'Age')

# %%
plt.pie(df7.Age , labels = df7.index , autopct ="%1.02f%%" , colors =["red","purple"])
plt.title("Relation between Attrion and Age" , color ="lime")
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df7.corr().round(2) , annot=True)
# Out:
# <Axes: >

# %%
at.head(5)
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
at1 = at[(at.Age > 17) & (at.BusinessTravel == 'Travel_Rarely')]

# Violin plot
sns.violinplot(x='Department', y='Attrition', data=at1)
plt.grid()
plt.show()

# %%
sns.jointplot(x='Age' , y='Attrition' , kind = "hex" , data = at);
